# %%
data = [10, 20, 30, 40]
print("Head:", data[0])
# Out:
# Head: 10

# %%
data = [10, 20, 30, 40]
print("Tail:", data[-1])
# Out:
# Tail: 40

# %%
data = [10, 20, 5, 40]
print("Minimum:", min(data))
# Out:
# Minimum: 5

# %%
data = [10, 20, 5, 40]
print("Maximum:", max(data))
# Out:
# Maximum: 40

# %%
import numpy as np
data = np.array([[1, 2], [3, 4]])
print("Dimension:", data.ndim)
# Out:
# Dimension: 2

# %%
import numpy as np
array = np.array([20,30,50])
print("array:\n",array)
print("Head:",array[0])
print("Tail:",array[-1])
print("Minimum:",array.min())
print("Maximum:",array.max())
print("Dimension:",array.ndim,"D")
# Out:
# array:
#  [20 30 50]
# Head: 20
# Tail: 50
# Minimum: 20
# Maximum: 50
# Dimension: 1 D

# %%
import numpy as np
arr = np.array([10, 20, 30, 40])
print(arr.size)
# Out:
# 4

# %%
arr = np.array([[1, 2, 3],
                [4, 5, 6]])
print(arr.shape)
# Out:
# (2, 3)

# %%
print(arr.dtype)
# Out:
# int32

# %%
print(arr.sum())
# Out:
# 21

# %%
print(arr.mean())
# Out:
# 3.5

# %%
print(np.median(arr))
# Out:
# 3.5

# %%
print(np.std(arr))
# Out:
# 1.707825127659933

# %%
print(np.var(arr))
# Out:
# 2.9166666666666665

# %%
print(np.sort(arr))
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr2 = np.array([1, 2, 2, 3, 4, 4])
print(np.unique(arr2))
# Out:
# [1 2 3 4]

# %%
print(arr.argmin())  
print(arr.argmax())
# Out:
# 0
# 5

# %%
print(arr[::-1])
# Out:
# [[4 5 6]
#  [1 2 3]]

# %%
import pandas as pd
data = {
    "A": [10, 20, 30],
    "B": [40, 50, 60]
}
df = pd.DataFrame(data)
print(df.columns)     
print(df["A"])         
print(df.mean())
# Out:
# Index(['A', 'B'], dtype='object')
# 0    10
# 1    20
# 2    30
# Name: A, dtype: int64
# A    20.0
# B    50.0
# dtype: float64
